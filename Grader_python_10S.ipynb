# %%
import numpy as np
import pandas as pd

# %%
student = ['Lê Quốc Thiện', 'Lê Thị Thanh Xuân', 'Đỗ Hoàng Khánh', 'Thân Văn Đông', 'Vũ Huỳnh', 'Nguyễn Hữu Linh Chi', 'Trịnh Thu Hương', 'Phú', 
          'Nguyễn Thế Hồng Khê', 'Phạm Văn Sĩ', 'Văn Hải Dương', 'Nguyễn Đức Tuấn Vinh', 'Nguyễn Hoàng Khánh An', 'Lê Nguyên Khang', 'Nguyễn Quí Long', 
          'Lê Phạm Ngọc Thảo', 'Phạm Nguyễn Thu Hằng']

# %%
np.random.shuffle(student)
student_df = pd.DataFrame(student, columns=['grader'])
np.random.shuffle(student)
student_df['student'] = student
student_df
# Out:
#                    grader                student
# 0          Đỗ Hoàng Khánh        Lê Nguyên Khang
# 1     Nguyễn Hữu Linh Chi   Nguyễn Đức Tuấn Vinh
# 2             Phạm Văn Sĩ               Vũ Huỳnh
# 3         Lê Nguyên Khang    Nguyễn Hữu Linh Chi
# 4                     Phú        Nguyễn Quí Long
# 5           Lê Quốc Thiện        Trịnh Thu Hương
# 6    Nguyễn Đức Tuấn Vinh    Nguyễn Thế Hồng Khê
# 7     Nguyễn Thế Hồng Khê                    Phú
# 8         Nguyễn Quí Long  Nguyễn Hoàng Khánh An
# 9       Lê Phạm Ngọc Thảo   Phạm Nguyễn Thu Hằng
# 10               Vũ Huỳnh          Lê Quốc Thiện
# 11      Lê Thị Thanh Xuân      Lê Phạm Ngọc Thảo
# 12  Nguyễn Hoàng Khánh An            Phạm Văn Sĩ
# 13          Văn Hải Dương      Lê Thị Thanh Xuân
# 14        Trịnh Thu Hương          Văn Hải Dương
# 15   Phạm Nguyễn Thu Hằng         Đỗ Hoàng Khánh
# 16          Thân Văn Đông          Thân Văn Đông

# %%
student_df.to_excel('grader.xlsx', index=False)
